# %%
import pandas as pd

# %%
mdh=pd.read_csv(r"C:\Users\USER\Documents\Book1.csv")

# %%
mdh
# Out:
#     product_id                                              Title  \
# 0      PSG2004  Kit Cat Classic Antibacterial Silica Crystal C...
# 1      PSG2005  Kit Cat Classic Antibacterial Silica Cat Litte...
# 2      PSG2006  Taste of the Wild Sierra Mountain Wet Dog Food...
# 3      PSG2007  Redbarn Chicken Recipe Semi-Moist Dog Food wit...
# 4      PSG2008  Redbarn Naturals Original Bully Slice Chew Dog...
# ..         ...                                                ...
# 96     PSG2100  Synergy Labs Groomer's Blend Ultra White Shamp...
# 97     PSG2101           Ferplast Medium Blue Dog Leash (120x2cm)
# 98     PSG2102       Golden Panda Orange Pet Collar (30-40x1.5cm)
# 99     PSG2103  Redbarn Large Filled Bone Dog Treat Peanut But...
# 100    PSG2104  Redbarn Small Filled Bone Dog Treat Chicken Fl...
#
#      description  Unnamed: 3 image link  sku_number       Barcode categories  \
# 0            NaN         NaN        5 L         NaN  8.858789e+12       shop
# ...

# %%
import urllib.parse

# %%
for x in mdh['Title']:
    query = x
    encoded_query = urllib.parse.quote(query)

    link2 = "https://www.walmart.com/search?q=" + encoded_query

    print(link2)
# Out:
# https://www.walmart.com/search?q=Kit%20Cat%20Classic%20Antibacterial%20Silica%20Crystal%20Cat%20Litter%20Mix%20Berry%20Scent%20-%20non%20toxic
# https://www.walmart.com/search?q=Kit%20Cat%20Classic%20Antibacterial%20Silica%20Cat%20Litter%20Crystals%20Lavender%20Scent%20-%20non%20toxic
# https://www.walmart.com/search?q=Taste%20of%20the%20Wild%20Sierra%20Mountain%20Wet%20Dog%20Food%20with%20Lamb%20in%20Gravy%20-%20grain%20free
# https://www.walmart.com/search?q=Redbarn%20Chicken%20Recipe%20Semi-Moist%20Dog%20Food%20with%20Added%20Vitamins%20%26%20Minerals%20-%20artificial%20colors%2C%20preservatives%20%26%20flavors%20free
# https://www.walmart.com/search?q=Redbarn%20Naturals%20Original%20Bully%20Slice%20Chew%20Dog%20Treats%20-%20grains%20free%2C%20gluten%20free%2C%20preservatives%20free
# https://www.walmart.com/search?q=Kit%20Cat%20Classic%20Antibacterial%20Silica%20Crystal%20Cat%20Litter%20Lemon%20Scent%20-%20non%20toxic
# ...

# %%
for x in mdh['Title']:
    mdh['']

# %%
link2_list = []
for x in mdh['Title']:
    query = x
    encoded_query = urllib.parse.quote(query)
    link2 = "https://www.walmart.com/search?q=" + encoded_query
    link2_list.append(link2)

link2_df = pd.DataFrame(link2_list, columns=['link2'])

# %%
mdh['image link']=link2_df

# %%
mdh
# Out:
#     product_id                                              Title  \
# 0      PSG2004  Kit Cat Classic Antibacterial Silica Crystal C...
# 1      PSG2005  Kit Cat Classic Antibacterial Silica Cat Litte...
# 2      PSG2006  Taste of the Wild Sierra Mountain Wet Dog Food...
# 3      PSG2007  Redbarn Chicken Recipe Semi-Moist Dog Food wit...
# 4      PSG2008  Redbarn Naturals Original Bully Slice Chew Dog...
# ..         ...                                                ...
# 96     PSG2100  Synergy Labs Groomer's Blend Ultra White Shamp...
# 97     PSG2101           Ferplast Medium Blue Dog Leash (120x2cm)
# 98     PSG2102       Golden Panda Orange Pet Collar (30-40x1.5cm)
# 99     PSG2103  Redbarn Large Filled Bone Dog Treat Peanut But...
# 100    PSG2104  Redbarn Small Filled Bone Dog Treat Chicken Fl...
#
#      description  Unnamed: 3  \
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# ...

# %%
def categorize_subtitle(atitle):
    if 'fetcher' in atitle.lower():
        return 'brushes and trimmers'
    elif 'poop' in atitle.lower():
        return 'litters and accessories'
    elif 'wet' in atitle.lower():
        return 'wet food'
    elif 'dry' in atitle.lower():  
        return 'dry food'
    elif 'toy' in atitle.lower():
        return 'toys'
    elif 'scent' in atitle.lower():
        return 'perfumes'
    elif 'milk' in atitle.lower():
        return 'all items'
    elif 'treats' in atitle.lower():
        return 'treats'
    elif 'fat' in atitle.lower():
        return 'dry food'
    elif 'shampoo' in atitle.lower():
        return 'shampoo and wash'
    elif 'nail' in atitle.lower():
        return 'brushes and trimmers'
    elif 'waste' in atitle.lower():
        return 'litter and accessories'
    elif 'alcott' in atitle.lower():
        return 'harness collar and leashes'
    elif 'crate' in atitle.lower():
        return 'crate and travels'
    elif 'bowl' in atitle.lower():
        return 'bowl and fountains'
    elif 'diapers' in atitle.lower():
        return 'blankets and covers'
    elif 'pads' in atitle.lower():
        return 'blankets and covers'
    elif 'remover' in atitle.lower():
        return 'all items'
    elif 'toys' in atitle.lower():
        return 'toys'
    elif 'training' in atitle.lower():
        return 'training aid'
    elif 'Spray' in atitle.lower():
        return 'perfumes'
    elif 'paws' in atitle.lower():
        return 'hair skin and nail care'
    elif 'wipes' in atitle.lower():
        return 'shampoo and washes'
    elif 'flakes' in atitle.lower():
        return 'dry food'
    elif 'meat' in atitle.lower():
        return 'treats'
    elif 'catnip' in atitle.lower():
        return 'toys and scratchers'
    elif 'chicken' in atitle.lower():
        return 'dry food'
    elif 'goodboy' in atitle.lower():
        return 'dry food'
    elif 'beaphar' in atitle.lower():
        return 'dry food'
    elif 'happy' in atitle.lower():
        return 'dry food'
    elif 'dog food' in atitle.lower():
        return 'dry food'
    elif 'cat food' in atitle.lower():
        return 'dry foods'
    elif 'mix' in atitle.lower():
        return 'dry food'
    elif 'brush' in atitle.lower():
        return 'dry foodbrushes and trimmers'
    elif 'eliminator' in atitle.lower():
        return 'flea, thick and deworming'
    elif 'flea' in atitle.lower():
        return 'flea, thicks and deworming'
    elif 'thicks' in atitle.lower():
        return 'flea,thicks and deworming'
    elif 'bird food' in atitle.lower():
        return 'bird feed'
    elif 'paw' in atitle.lower():
        return 'hair skin and nail care'
    elif 'dental' in atitle.lower():
        return 'eye ear and dental care'
    elif 'conditioner' in atitle.lower():
        return 'shampoo and washes'
    elif 'teeth' in atitle.lower():
        return 'dental care'
    elif 'tooth paste' in atitle.lower():
        return 'dental care'
    elif 'dust' in atitle.lower():
        return 'brushes and trimmers'
    elif 'hay' in atitle.lower():
        return 'dry food'
    elif 'multivitamin' in atitle.lower():
        return 'general and health suppliments'
    elif 'vit' in atitle.lower():
        return 'general and health suppliments'
    elif 'dachshunds' in atitle.lower():
        return 'dry food'
    elif 'ear' in atitle.lower():
        return 'ear care'
    elif 'snacks' in atitle.lower():
        return 'dry food'
    elif 'hamster' in atitle.lower():
        return 'hamster rabbit and others'
    elif 'leash' in atitle.lower():
        return 'harness collars and leashes'
    elif 'dried' in atitle.lower():
        return 'hamster rabbit and others'
    elif 'itchstick' in atitle.lower():
        return ' brushes and trimmers'
    elif 'scratcher' in atitle.lower():
        return 'all items'
    elif 'tank' in atitle.lower():
        return 'bowl and fountains'
    elif 'padovan' in atitle.lower():
        return 'bird food and treats'
    elif 'padovan woody litter' in atitle.lower():
        return 'litter box'
    elif 'bites' in atitle.lower():
        return 'treats'
    elif 'foam' in atitle.lower():
        return 'shampoo and wash'
    elif 'stick food' in atitle.lower():
        return 'food and chew'
    elif 'cologne' in atitle.lower():
        return 'perfumes'
    elif 'cat food' in atitle.lower():
        return 'dry food'
    elif 'dog food' in atitle.lower():
        return 'dry food'
    elif 'eye' in atitle.lower():
        return 'eye care'
    elif 'bone' in atitle.lower():
        return 'treats'
    elif 'tent' in atitle.lower():
        return 'crates and travel'
    elif 'cat grass' in atitle.lower():
        return 'blankets and covers'
    elif 'fish food' in atitle.lower():
        return 'food'
    elif 'rodents' in atitle.lower():
        return 'food and chew'
    elif 'antislip' in atitle.lower():
        return 'training aid'
    elif 'dog grooming' in atitle.lower():
        return 'all items'
    elif 'supplement' in atitle.lower():
        return 'health and supplement'
    elif 'aquarium' in atitle.lower():
        return 'bowls and fountains'
    elif 'chew' in atitle.lower():
        return 'toys'
    elif 'collars' in atitle.lower():
        return 'harness collars and leashes'
    elif 'cat lint' in atitle.lower():
        return 'toys and scratchers'
    elif 'dog harness' in atitle.lower():
        return 'harness collars and leashes'
    elif 'comb' in atitle.lower():
        return 'hair care'
    elif 'Litter' in atitle.lower():
        return 'litter box'
    elif 'blue' in atitle.lower():
        return 'litter box'
    elif 'Aquafin' in atitle.lower():
        return 'dry food'
    elif 'Spray' in atitle.lower():
        return 'perfumes'
    elif 'tennis' in atitle.lower():
        return 'toys'
    elif 'bounce' in atitle.lower():
        return 'toys'
    elif 'deodorant' in atitle.lower():
        return 'perfumes'
    elif 'Toothpaste' in atitle.lower():
        return 'dental care'
    elif 'repellant' in atitle.lower():
        return 'spray'
    elif 'Litter' in atitle.lower():
        return 'litter box'
    elif 'Imac' in atitle.lower():
        return 'litter box'
    elif 'enhancing' in atitle.lower():
        return 'all items'
    elif 'starter' in atitle.lower():
        return 'dry food'
    elif 'pate' in atitle.lower():
        return 'antistress'
    elif 'spray' in atitle.lower():
        return 'perfumes and spray'
    elif 'magical' in atitle.lower():
        return 'perfume'
    elif 'natural' in atitle.lower():
        return 'all items'
    elif 'Diaper' in atitle.lower():
        return 'body cover'
    elif 'Litter tray' in atitle.lower():
        return 'litter and accessories'
    elif 'drinkwell' in atitle.lower():
        return 'all items'
    elif 'Bed' in atitle.lower():
        return 'beds'
    elif 'sand' in atitle.lower():
        return 'litter'
    elif 'oxyfresh' in atitle.lower():
        return 'perfumes'
    elif 'wee-wee' in atitle.lower():
        return 'litter and accessories'
    elif 'goldfish' in atitle.lower():
        return 'fish food'
    
    
    else:
        return 'all items'
mdh['subcategories'] = mdh['Title'].apply(categorize_subtitle)

# %%
def categoriz_subtitl(atitle):
    if 'fetcher' in atitle.lower():
        return 'grooming'
    elif 'poop' in atitle.lower():
        return 'litters'
    elif 'wet' in atitle.lower():
        return 'food and treats'
    elif 'dry' in atitle.lower():  
        return 'food and treats'
    elif 'toy' in atitle.lower():
        return 'toys and accessories'
    elif 'scent' in atitle.lower():
        return 'grooming'
    elif 'milk' in atitle.lower():
        return 'food and treats'
    elif 'treats' in atitle.lower():
        return 'food and treats'
    elif 'fat' in atitle.lower():
        return 'food and treats'
    elif 'shampoo' in atitle.lower():
        return 'grooming'
    elif 'nail' in atitle.lower():
        return 'grooming'
    elif 'waste' in atitle.lower():
        return 'litter and accessories'
    elif 'alcott' in atitle.lower():
        return 'toys and accessories'
    elif 'crate' in atitle.lower():
        return 'toys and accessories'
    elif 'bowl' in atitle.lower():
        return 'toys and accessories'
    elif 'diapers' in atitle.lower():
        return 'grooming'
    elif 'pads' in atitle.lower():
        return 'toys and accessories'
    elif 'remover' in atitle.lower():
        return 'grooming'
    elif 'toys' in atitle.lower():
        return 'toys and accessories'
    elif 'training' in atitle.lower():
        return 'toys and accessories'
    elif 'Spray' in atitle.lower():
        return 'grooming'
    elif 'paws' in atitle.lower():
        return 'toys and accessories'
    elif 'wipes' in atitle.lower():
        return 'grooming'
    elif 'flakes' in atitle.lower():
        return 'food and treats'
    elif 'meat' in atitle.lower():
        return 'food and treats'
    elif 'catnip' in atitle.lower():
        return 'cat toys and accessories'
    elif 'chicken' in atitle.lower():
        return 'food and treats'
    elif 'goodboy' in atitle.lower():
        return 'food and treats'
    elif 'beaphar' in atitle.lower():
        return 'food and treats'
    elif 'happy' in atitle.lower():
        return 'food and treats'
    elif 'dog food' in atitle.lower():
        return 'dog food and treats'
    elif 'cat food' in atitle.lower():
        return 'cat food and treats'
    elif 'mix' in atitle.lower():
        return 'food and treats'
    elif 'brush' in atitle.lower():
        return 'grooming'
    elif 'eliminator' in atitle.lower():
        return 'health'
    elif 'flea' in atitle.lower():
        return 'dog health'
    elif 'thicks' in atitle.lower():
        return 'dog health'
    elif 'bird food' in atitle.lower():
        return 'bird food'
    elif 'paw' in atitle.lower():
        return 'cat toys and accessories'
    elif 'dental' in atitle.lower():
        return 'health'
    elif 'conditioner' in atitle.lower():
        return 'grooming'
    elif 'teeth' in atitle.lower():
        return 'dental care'
    elif 'tooth paste' in atitle.lower():
        return 'health'
    elif 'dust' in atitle.lower():
        return 'grooming'
    elif 'hay' in atitle.lower():
        return 'food and treats'
    elif 'multivitamin' in atitle.lower():
        return 'health suppliments'
    elif 'vit' in atitle.lower():
        return 'health '
    elif 'dachshunds' in atitle.lower():
        return 'food and treats'
    elif 'ear' in atitle.lower():
        return 'health'
    elif 'snacks' in atitle.lower():
        return 'food and treats'
    elif 'hamster' in atitle.lower():
        return 'hamster rabbit and others'
    elif 'leash' in atitle.lower():
        return 'toys and accessories'
    elif 'dried' in atitle.lower():
        return 'hamster rabbit and others'
    elif 'itchstick' in atitle.lower():
        return ' grooming'
    elif 'scratcher' in atitle.lower():
        return 'toys and accessories'
    elif 'tank' in atitle.lower():
        return 'toys and accessories'
    elif 'padovan' in atitle.lower():
        return 'bird food and treats'
    elif 'padovan woody litter' in atitle.lower():
        return 'litter box'
    elif 'bites' in atitle.lower():
        return 'dog food and treats'
    elif 'foam' in atitle.lower():
        return 'grooming'
    elif 'stick food' in atitle.lower():
        return 'food and treats'
    elif 'cologne' in atitle.lower():
        return 'grooming'
    elif 'cat food' in atitle.lower():
        return 'cat food'
    elif 'dog food' in atitle.lower():
        return 'dog food'
    elif 'eye' in atitle.lower():
        return 'health care'
    elif 'bone' in atitle.lower():
        return 'food and treats'
    elif 'tent' in atitle.lower():
        return 'crates and travel'
    elif 'cat grass' in atitle.lower():
        return 'toys and accessories'
    elif 'fish food' in atitle.lower():
        return 'fish food'
    elif 'rodents' in atitle.lower():
        return 'food'
    elif 'antislip' in atitle.lower():
        return 'toys and accessories'
    elif 'dog grooming' in atitle.lower():
        return 'toys and accessories'
    elif 'supplement' in atitle.lower():
        return 'health'
    elif 'aquarium' in atitle.lower():
        return 'toys and accessories'
    elif 'chew' in atitle.lower():
        return 'toys and accessories'
    elif 'collars' in atitle.lower():
        return 'toys and accessories'
    elif 'cat lint' in atitle.lower():
        return 'toys and accessories'
    elif 'dog harness' in atitle.lower():
        return 'toys and accessories'
    elif 'comb' in atitle.lower():
        return 'grooming'
    elif 'Litter' in atitle.lower():
        return 'litter'
    elif 'blue' in atitle.lower():
        return 'litter'
    elif 'Aquafin' in atitle.lower():
        return 'food and treats'
    elif 'Spray' in atitle.lower():
        return 'grooming'
    elif 'tennis' in atitle.lower():
        return 'toys and accessories'
    elif 'bounce' in atitle.lower():
        return 'toys and accessories'
    elif 'deodorant' in atitle.lower():
        return 'grooming'
    elif 'Toothpaste' in atitle.lower():
        return 'health care'
    elif 'repellant' in atitle.lower():
        return 'grooming'
    elif 'Litter' in atitle.lower():
        return 'litter box'
    elif 'Imac' in atitle.lower():
        return 'litter box'
    elif 'enhancing' in atitle.lower():
        return 'food and treats'
    elif 'starter' in atitle.lower():
        return 'food and treats'
    elif 'pate' in atitle.lower():
        return 'health'
    elif 'spray' in atitle.lower():
        return 'grooming'
    elif 'magical' in atitle.lower():
        return 'grooming'
    elif 'natural' in atitle.lower():
        return 'care'
    elif 'Diaper' in atitle.lower():
        return 'grooming'
    elif 'Litter tray' in atitle.lower():
        return 'litter'
    elif 'drinkwell' in atitle.lower():
        return 'food and treats'
    elif 'Bed' in atitle.lower():
        return 'toys and accessories'
    elif 'sand' in atitle.lower():
        return 'cat litter'
    elif 'oxyfresh' in atitle.lower():
        return 'grooming'
    elif 'wee-wee' in atitle.lower():
        return 'litter'
    elif 'goldfish' in atitle.lower():
        return 'fish food'
    
    
    else:
        return 'pet accessories'
mdh['child categories'] = mdh['Title'].apply(categoriz_subtitl)

# %%
mdh
# Out:
#     product_id                                              Title  \
# 0      PSG2004  Kit Cat Classic Antibacterial Silica Crystal C...
# 1      PSG2005  Kit Cat Classic Antibacterial Silica Cat Litte...
# 2      PSG2006  Taste of the Wild Sierra Mountain Wet Dog Food...
# 3      PSG2007  Redbarn Chicken Recipe Semi-Moist Dog Food wit...
# 4      PSG2008  Redbarn Naturals Original Bully Slice Chew Dog...
# ..         ...                                                ...
# 96     PSG2100  Synergy Labs Groomer's Blend Ultra White Shamp...
# 97     PSG2101           Ferplast Medium Blue Dog Leash (120x2cm)
# 98     PSG2102       Golden Panda Orange Pet Collar (30-40x1.5cm)
# 99     PSG2103  Redbarn Large Filled Bone Dog Treat Peanut But...
# 100    PSG2104  Redbarn Small Filled Bone Dog Treat Chicken Fl...
#
#      description  Unnamed: 3  \
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# ...

# %%
mdh.to_csv('final sheet 2 copy.csv', index=False)

# exporting to excel
mdh.to_excel('final sheet 2 copy.xlsx', index=False)
